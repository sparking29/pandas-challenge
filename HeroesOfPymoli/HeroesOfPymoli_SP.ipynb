# %% [markdown]
# ### Observations
# * Players are skewed mainly Male
# * Males pay less than Women for play
# * Most players are 15-30 years old. Few players are 40+
# * Verdict and Phantomlight are the most popular and most value driving items

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
# Get a list of all of our columns for easy reference
purchase_data.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %%
#Display total players
players= len(purchase_data["SN"].value_counts())
players
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Find/Assign calculations
Items = len(purchase_data["Item Name"].unique())
Avg_Price = purchase_data["Price"].mean()
Purchases = len(purchase_data["Item Name"])
Revenue = purchase_data["Price"].sum()

# Create new DataFrame
Purchasing_Analysis = pd.DataFrame({"Number of Unique Items": [Items],
                                    "Average Price": [Avg_Price],
                                    "Number of Purchases": [Purchases],
                                    "Total Revenue": [Revenue]})
Purchasing_Analysis
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#Find/Assign Calculations
gender = purchase_data[["SN", "Gender"]]
gender.head()
# Out:
#               SN Gender
# 0        Lisim78   Male
# 1    Lisovynya38   Male
# 2     Ithergue48   Male
# 3  Chamassasya86   Male
# 4      Iskosia90   Male

# %%
#create genders
gender = gender.drop_duplicates()

counts = gender["Gender"].value_counts()

total_counts = [counts[0],counts[1],counts[2]]
percents = [round((counts[0]/players)*100,2),round((counts[1]/players)*100,2),round((counts[2]/players)*100,2)]

# %%
# new dataframe
gender_df = pd.DataFrame({ "Percentage of Players": percents,"Total Count": total_counts
})
gender_df.index = (["Male", "Female", "Other"])
gender_df
# Out:
#         Percentage of Players  Total Count
# Male                    84.03          484
# Female                  14.06           81
# Other                    1.91           11

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Group by gender
gender = purchase_data.groupby(["Gender"])

# %%
#Basic Calculations
Purchase_Count = gender["SN"].count()
Purchase_Price = gender["Price"].mean()
Per_Person = gender["Price"].sum()

# %%
#Another Dataframe
Gender_Analysis = pd.DataFrame({"Purchase Count": Purchase_Count,
                              "Avg. Purchase Price": Purchase_Price,
                              "Avg. Purchase Value": Per_Person})

Gender_Analysis
# Out:
#                        Purchase Count  Avg. Purchase Price  \
# Gender
# Female                            113             3.203009
# Male                              652             3.017853
# Other / Non-Disclosed              15             3.346000
#
#                        Avg. Purchase Value
# Gender
# Female                              361.94
# Male                               1967.64
# Other / Non-Disclosed                50.19

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Create Bins
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#And Another Dataframe
purchase_data["Age Demographics"]= pd.cut(purchase_data["Age"], age_bins, labels=group_names)
demographic_group =purchase_data.groupby("Age Demographics")

demographic_group.head()
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 5              5        Yalae81   22                   Male       81
# 6              6      Itheria73   36                   Male      169
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 14            14    Saesrideu94   35                   Male      165
# 19            19      Chamalo71   30                   Male       89
# 22            22   Siarithria38   38  Other / Non-Disclosed       24
# 23            23       Eyrian71   40                   Male      151
# 24            24        Siala43   30                   Male      141
# ...

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#groupby age
PA_DF = purchase_data.groupby("Age Demographics")
PA_DF_Count=PA_DF["SN"].nunique()
PA_DF_Count
# Out:
# Age Demographics
# <10       17
# 10-14     22
# 15-19    107
# 20-24    258
# 25-29     77
# 30-34     52
# 35-39     31
# 40+       12
# Name: SN, dtype: int64

# %%
#calculations
AgePurchaseCount=PA_DF["Purchase ID"].count()
AgePurchaseAvg=PA_DF["Price"].mean()
AgeTotalValue=PA_DF["Price"].sum()
AgeTotalPerAvg= AgeTotalValue / PA_DF_Count

#new dataframe for calcs
AgeData_df = pd.DataFrame({"Total Purchase": AgePurchaseCount,
                          "Average Purchase Price": AgePurchaseAvg,
                          "Total Value": AgeTotalValue,
                          "Average Price Per Person": AgeTotalPerAvg})

AgeData_df
# Out:
#                   Total Purchase  Average Purchase Price  Total Value  \
# Age Demographics
# <10                           23                3.353478        77.13
# 10-14                         28                2.956429        82.78
# 15-19                        136                3.035956       412.89
# 20-24                        365                3.052219      1114.06
# 25-29                        101                2.900990       293.00
# 30-34                         73                2.931507       214.00
# 35-39                         41                3.601707       147.67
# 40+                           13                2.941538        38.24
#
#                   Average Price Per Person
# Age Demographics
# <10                               4.537059
# 10-14                             3.762727
# 15-19                             3.858785
# 20-24                             4.318062
# 25-29                             3.805195
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
top_spenders = purchase_data['Item ID'].groupby(purchase_data['SN']).count()

# new dataframe
top_spenders= pd.DataFrame(data=top_spenders)
top_spenders.columns = ['Purchase Count']

top_spenders['Average Purchase Price'] = round(purchase_data['Price'].groupby(purchase_data['SN']).mean(),2)
top_spenders['Total Purchase Value'] = purchase_data['Price'].groupby(purchase_data['SN']).sum()

top_spenders.head()
# Out:
#               Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Adairialis76               1                    2.28                  2.28
# Adastirin33                1                    4.48                  4.48
# Aeda94                     1                    4.91                  4.91
# Aela59                     1                    4.32                  4.32
# Aelaria33                  1                    1.79                  1.79

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#define most items 
most_items = purchase_data.groupby(['Item ID', 'Item Name','Price'])['Price'].agg(['count','sum'])
most_items.columns = ['Purchase Count', 'Total Purchase Value']

# set the index back at zero 
most_items.reset_index(inplace=True)
most_items.set_index(['Item ID','Item Name'] ,inplace=True)

most_items = most_items[['Purchase Count', 'Price', 'Total Purchase Value']]

most_items.head()
# Out:
#                             Purchase Count  Price  Total Purchase Value
# Item ID Item Name
# 0       Splinter                         4   1.28                  5.12
# 1       Crucifer                         3   3.26                  9.78
# 2       Verdict                          6   2.48                 14.88
# 3       Phantomlight                     6   2.49                 14.94
# 4       Bloodlord's Fetish               5   1.70                  8.50

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
#sort
most_items.sort_values(by='Total Purchase Value', ascending=False)

most_items.head()
# Out:
#                             Purchase Count  Price  Total Purchase Value
# Item ID Item Name
# 0       Splinter                         4   1.28                  5.12
# 1       Crucifer                         3   3.26                  9.78
# 2       Verdict                          6   2.48                 14.88
# 3       Phantomlight                     6   2.49                 14.94
# 4       Bloodlord's Fetish               5   1.70                  8.50
